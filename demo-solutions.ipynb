# %%
# demo 2
myName = "pete"
print(myName)
# Out:
# pete

# %%
# demo 3
from numpy import random as rn
rn.randn()
myRand = rn.randn()
print(myRand)
# Out:
# 1.7058241608041527

# %%
# demo 4
data = []
for i in range(10000):
    data.append(rn.randn())
    
print(data)
# Out:
# [0.7597351792465514, -0.011440538095280485, -0.5904503951057952, -0.8633939952694926, 1.781261368830137, -0.8251179305907752, 1.7437111621768977, 0.7567132185276083, 1.1172618755356152, -0.50135810858739, -1.398856304692269, 0.668742113687916, 0.948979058801409, 0.5028904310576958, -2.3844165468317655, -0.8020107984280269, 0.512838207509418, -0.6605028638382618, 0.7478967420869589, 0.22121329383241933, 0.7122638129573164, -0.504006371498922, -0.33693641482455317, -0.03828358928417768, -0.3949843145052881, -1.092396062201059, -0.9458946215179513, 0.4492631119847454, -0.8270956243487609, 0.7428742311156555, -0.7266411881797853, -0.49735906232212074, 0.06514523409207967, -0.3748189535297323, -1.9465694744753115, 1.1960647586546251, 0.8679176421785155, 0.708709404332511, 0.32576793170023083, 0.36179094040001647, -0.7696532315647066, 0.7067589778274789, -0.7867879860971804, 1.1946988771807416, -0.5972002526617975, 1.629786032095719, 0.617442217760042, -1.1469449544357044, 1.25175194528737
# ...

# %%
# demo 5
# Import the library
import matplotlib.pyplot as plt
# matplotlib histogram
plt.hist(data,bins=33)
# Out:
# (array([  3.,   7.,  11.,  23.,  34.,  54., 106., 160., 205., 310., 388.,
#         511., 630., 747., 742., 812., 828., 830., 743., 685., 546., 472.,
#         331., 266., 195., 141.,  82.,  54.,  36.,  23.,  11.,   6.,   8.]),
#  array([-3.44786905, -3.23683018, -3.02579132, -2.81475246, -2.60371359,
#         -2.39267473, -2.18163587, -1.970597  , -1.75955814, -1.54851927,
#         -1.33748041, -1.12644155, -0.91540268, -0.70436382, -0.49332496,
#         -0.28228609, -0.07124723,  0.13979164,  0.3508305 ,  0.56186936,
#          0.77290823,  0.98394709,  1.19498595,  1.40602482,  1.61706368,
#          1.82810254,  2.03914141,  2.25018027,  2.46121914,  2.672258  ,
#          2.88329686,  3.09433573,  3.30537459,  3.51641345]),
#  <a list of 33 Patch objects>)
